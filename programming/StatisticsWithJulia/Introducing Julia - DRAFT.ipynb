# %% [markdown]
# Test
# ====
#
# **Author:** GTrunSec
#
# **Date:** 2021-01-04 Mon 23:58

# %% [markdown]
# # Table of Contents

# %% [markdown]
# ## Introducing Julia - DRAFT:PROPERTIES:

# %% [markdown]
# ### Link on page 15: [https://github.com/h-Klok/StatsWithJuliaBook](https://github.com/h-Klok/StatsWithJuliaBook):PROPERTIES:

# %% [markdown]
# ### Language Overview:PROPERTIES:

# %% [markdown]
# #### Link on page 16: [https://julialang.org/](https://julialang.org/):PROPERTIES:

# %% [markdown]
# #### Link on page 17: [Hello world and perfect squares](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/helloWorld.jl):PROPERTIES:

# %% [markdown]
# #### Link on page 18: [Using a comprehension](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/comprehension.jl):PROPERTIES:

# %% [markdown]
# #### Link on page 19: [https://docs.julialang.org](https://docs.julialang.org):PROPERTIES:

# %% [markdown]
# #### Link on page 19: [https://docs.julialang.org/](https://docs.julialang.org/):PROPERTIES:

# %% [markdown]
# #### Link on page 21: [Slow code example](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/slow.jl):PROPERTIES:

# %%
using Statistics

@time begin
    data = Float64[]
    for _ in 1:10^6
        group = Float64[]
        for _ in 1:5*10^2
            push!(group,rand())
        end
        push!(data,mean(group))
    end
    println("98% of the means lie in the estimated range: ",
                (quantile(data,0.01),quantile(data,0.99)) )
end

# %% [markdown]
# #### Link on page 21: [Fast code example](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/fast.jl):PROPERTIES:

# %%
using Statistics

@time begin
    data = [mean(rand(5*10^2)) for _ in 1:10^6]
    println("98% of the means lie in the estimated range: ",
                    (quantile(data,0.01),quantile(data,0.99)) )
end
# Out:
# 98% of the means lie in the estimated range: (0.46996439638573045, 0.5300740324223876)
#   1.127390 seconds (1.74 M allocations: 3.936 GiB, 7.61% gc time)

# %% [markdown]
# #### Link on page 23: [https://docs.julialang.org/en/v1/manual/variables-and-scoping/](https://docs.julialang.org/en/v1/manual/variables-and-scoping/):PROPERTIES:

# %% [markdown]
# #### Link on page 24: [Variable scope and the global keyword](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/variableScope.jl):PROPERTIES:

# %% [markdown]
# ### Setup and Interface:PROPERTIES:

# %% [markdown]
# #### Link on page 25: [https://julialang.org/downloads/](https://julialang.org/downloads/):PROPERTIES:

# %% [markdown]
# #### Link on page 26: [the book’s](https://github.com/h-Klok/StatsWithJuliaBook):PROPERTIES:

# %% [markdown]
# ##### Link on page 26: [GitHub](https://github.com/h-Klok/StatsWithJuliaBook):PROPERTIES:

# %% [markdown]
# ##### Link on page 27: [https://julialang.org/packages/](https://julialang.org/packages/):PROPERTIES:

# %% [markdown]
# ##### Link to document on page 28: [\*Base.jl](QQQQ.pdf) (target page: 1):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [BSON.jl](https://github.com/JuliaIO/BSON.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Calculus.jl](https://github.com/JuliaMath/Calculus.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [CategoricalArrays.jl](https://github.com/JuliaData/CategoricalArrays.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Clustering.jl](https://github.com/JuliaStats/Clustering.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Combinatorics.jl](https://github.com/JuliaMath/Combinatorics.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [CSV.jl](https://github.com/JuliaData/CSV.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [DataFrames.jl](https://github.com/JuliaData/DataFrames.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [DataStructures.jl](https://github.com/JuliaCollections/DataStructures.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [\*Dates.jl](https://github.com/JuliaLang/julia/blob/master/stdlib/Dates/docs/src/index.md):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [DecisionTree.jl](https://github.com/bensadeghi/DecisionTree.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [DifferentialEquations.jl](https://github.com/JuliaDiffEq/DifferentialEquations.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Distributions.jl](https://github.com/JuliaStats/Distributions.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Flux.jl](https://github.com/FluxML/Flux.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [GLM.jl](https://github.com/JuliaStats/GLM.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [HCubature.jl](https://github.com/stevengj/HCubature.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [HypothesisTests.jl](https://github.com/JuliaStats/HypothesisTests.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [HTTP.jl](https://github.com/JuliaWeb/HTTP.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [IJulia.jl](https://github.com/JuliaLang/IJulia.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [Images.jl](https://github.com/JuliaImages/Images.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 28: [JSON.jl](https://github.com/JuliaIO/JSON.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [Juno.jl](https://github.com/JunoLab/Juno.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [KernelDensity.jl](https://github.com/JuliaStats/KernelDensity.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [Lasso.jl](https://github.com/JuliaStats/Lasso.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [LaTeXStrings.jl](https://github.com/stevengj/LaTeXStrings.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [LIBSVM.jl](https://github.com/mpastell/LIBSVM.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [LightGraphs.jl](https://github.com/JuliaGraphs/LightGraphs.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [\*LinearAlgebra.jl](https://github.com/JuliaLang/julia/blob/master/stdlib/LinearAlgebra/docs/src/index.md):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [Measures.jl](https://github.com/JuliaGraphics/Measures.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [MLDatasets.jl](https://github.com/JuliaML/MLDatasets.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [MultivariateStats.jl](https://github.com/JuliaStats/MultivariateStats.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [NLsolve.jl](https://github.com/JuliaNLSolvers/NLsolve.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [Plots.jl](https://github.com/JuliaPlots/Plots.jl/):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [PyCall.jl](https://github.com/JuliaPy/PyCall.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [PyPlot.jl](https://github.com/JuliaPy/PyPlot.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [QuadGK.jl](https://github.com/JuliaMath/QuadGK.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [\*Random.jl](https://github.com/JuliaLang/julia/blob/master/stdlib/Random/docs/src/index.md):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [RCall.jl](https://github.com/JuliaInterop/RCall.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [RDatasets.jl](https://github.com/johnmyleswhite/RDatasets.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [Roots.jl](https://github.com/JuliaMath/Roots.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [SpecialFunctions.jl](https://github.com/JuliaMath/SpecialFunctions.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [\*Statistics.jl](https://github.com/JuliaLang/julia/blob/master/stdlib/Statistics/docs/src/index.md):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [StatsBase.jl](https://github.com/JuliaStats/StatsBase.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [StatsModels.jl](https://github.com/JuliaStats/StatsModels.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [StatsPlots.jl](https://github.com/JuliaPlots/StatsPlots.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 29: [TimeSeries.jl](https://github.com/JuliaStats/TimeSeries.jl):PROPERTIES:

# %% [markdown]
# #### Crash Course by Example:PROPERTIES:

# %% [markdown]
# ##### Link on page 30: [https://julialang.org/learning/](https://julialang.org/learning/):PROPERTIES:

# %% [markdown]
# ##### Link on page 31: [Bubble sort](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/bubbleSort.jl):PROPERTIES:

# %%
function bubbleSort!(a)
    n = length(a)
    for i in 1:n-1
        for j in 1:n-i
            if a[j] > a[j+1]
                a[j], a[j+1] = a[j+1], a[j]
            end
        end
    end
    return a
end

data = [65, 51, 32, 12, 23, 84, 68, 1]
bubbleSort!(data)
# Out:
# #+begin_example
# bubbleSort! (generic function with 1 method)
# 8-element Array{Int64,1}:
#  65
#  51
#  32
#  12
#  23
#  84
#  68
#   1
# 8-element Array{Int64,1}:
#   1
#  12
#  23
#  32
#  51
#  65
#  68
#  84
# #+end_example

# %% [markdown]
# ##### Link on page 32: [Roots of a polynomial](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/polyRoots.jl):PROPERTIES:

# %% [markdown]
# x=−3±√32−4(−10)2(−10)=3±720⇒x1= 0.5,  x2=−0.2

# %%
using Roots

function polynomialGenerator(a...)
    n = length(a)-1
    poly =  function(x)
                return sum([a[i+1]*x^i for i in 0:n])
            end
    return poly
end

polynomial = polynomialGenerator(1,3,-10)
zeroVals = find_zeros(polynomial,-10,10)
println("Zeros of the function f(x): ", zeroVals)
# Out:
# polynomialGenerator (generic function with 1 method)
# #1 (generic function with 1 method)

# %% [markdown]
# ##### Link on page 35: [Steady state of a Markov chain in several ways](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/multiWayMarkovChainStationary.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 37: [Web interface, JSON and string parsing](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/shakespeareWords.jl):PROPERTIES:

# %% [markdown]
# #### Plots, Images and Graphics:PROPERTIES:

# %% [markdown]
# ##### Link on page 38: [http://docs.juliaplots.org/](http://docs.juliaplots.org/):PROPERTIES:

# %% [markdown]
# ##### Link on page 39: [Note the use of the LaTeXStrings package enabling L A TEX formatted formulas. See for example, http://tug.ctan.org/info/undergradmath/undergradmath.pdf](http://tug.ctan.org/info/undergradmath/undergradmath.pdf):PROPERTIES:

# %% [markdown]
# ##### Link on page 39: [Basic plotting](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/plotSimple.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 41: [Histogram of hailstone sequence lengths](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/hailstoneHistogram.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 42: [Animated edges of a graph](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/graph.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 44: [Working with images](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/imageProcessing.jl):PROPERTIES:

# %% [markdown]
# #### Random Numbers and Monte Carlo Simulation:PROPERTIES:

# %% [markdown]
# ##### Link on page 46: [Pseudorandom number generation](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/seedExample.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 47: [Estimating π](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/piEstimate.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 48: [A linear congruential generator](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/lcg.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 51: [Random walks and seeds](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/randomWalks.jl):PROPERTIES:

# %% [markdown]
# #### Integration with Other Languages:PROPERTIES:

# %% [markdown]
# ##### Link on page 52: [Using R from Julia](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/usingR.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 53: [https://vincentarelbundock.github.io/Rdatasets/datasets.html](https://vincentarelbundock.github.io/Rdatasets/datasets.html):PROPERTIES:

# %% [markdown]
# ##### Link on page 54: [NLP via Python’s TextBlob](https://github.com/h-Klok/StatsWithJuliaBook/blob/master/1_chapter/usingPython.jl):PROPERTIES:

# %% [markdown]
# ##### Link on page 55: [https://github.com/JuliaInterop](https://github.com/JuliaInterop):PROPERTIES:
